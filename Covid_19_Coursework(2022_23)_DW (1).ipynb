# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('.\sql_db\Covid_19_Data.db')
cur = conn.cursor()

# %%
# create dimension table Time in database
cur.execute('''CREATE TABLE TIME_TABLE(
                T_ID INTEGER PRIMARY KEY NOT NULL,
                Year INTEGER  NULL,
                Month CHAR NULL,
                Date DATE NULL);
                ''')


# commit and save changes to database
conn.commit()

# %%
# create dimension table Virus in database
cur.execute('''CREATE TABLE VIRUS_TABLE(
                V_ID INTEGER PRIMARY KEY NOT NULL,
                Name CHAR  NULL,
                Type CHAR  NULL);
                ''')


# commit and save changes to database
conn.commit()

# %%
# create dimension table Location in database
cur.execute('''CREATE TABLE LOCATION_TABLE(
              L_ID INTEGER PRIMARY KEY NOT NULL,
                Country CHAR NULL,
                Region CHAR NULL,
                Population INTEGER NULL);
                ''')


# commit and save changes to database
conn.commit()

# %%
# create dimension table target Group in database
cur.execute('''CREATE TABLE TARGET_GROUP_TABLE(
              TRG_ID INTEGER PRIMARY KEY NOT NULL,
                Age_range CHAR NULL);
                ''')


# commit and save changes to database
conn.commit()

# %%
# create dimension table Vaccine in database
cur.execute('''CREATE TABLE VACCINE_TABLE(
              VAC_ID INTEGER PRIMARY KEY NOT NULL,
                Name CHAR NULL);
                ''')


# commit and save changes to database
conn.commit()

# %%
# create dimension table COVID19_FACT_TABLE in database
cur.execute('''CREATE TABLE COVID19_FACT_TABLE(

                T_ID INTEGER,
                L_ID INTEGER,
                V_ID INTEGER,
                VAC_ID INTEGER,
                TRG_ID INTEGER,
               Current_Cases INTEGER NULL,
               New_Cases INTEGER NULL,
               Recovered_Cases INTEGER NULL,
               Deaths INTEGER NULL,
               Doses_received INTEGER NULL,
               First_Dose INTEGER NULL,
               Second_Dose INTEGER NULL,
               Third_Dose INTEGER NULL,
               ICU_cases INTEGER NULL,
               Source CHAR NULL,
               FOREIGN KEY (T_ID) REFERENCES TIME_TABLE(T_ID ),
               FOREIGN KEY (L_ID) REFERENCES LOCATION_TABLE(L_ID ),
               FOREIGN KEY (V_ID) REFERENCES VIRUS_TABLE(V_ID ),
               FOREIGN KEY (VAC_ID) REFERENCES VACCINE_TABLE(VAC_ID ),
               FOREIGN KEY (TRG_ID) REFERENCES TARGET_GROUP_TABLE(TRG_ID)
               PRIMARY KEY(L_ID,T_ID,V_ID,VAC_ID,TRG_ID)
               );
                ''')


# commit and save changes to database
conn.commit()

# %%
# read excel file to insert into table column
dataframe_Time_Table = pd.read_excel('/content/Time Table.xlsx')
dataframe_Time_Table.to_sql('TIME_TABLE',conn,if_exists='replace',index=False)
conn.commit()

# %%
# read excel file to insert into table column
dataframe_VIRUS_TABLE = pd.read_excel('/content/Virus Table.xlsx')
dataframe_VIRUS_TABLE.to_sql('VIRUS_TABLE',conn,if_exists='replace',index=False)
conn.commit()

# %%
# read excel file to insert into table column
dataframe_LOCATION_TABLE = pd.read_excel('/content/Location Table.xlsx')
dataframe_LOCATION_TABLE.to_sql('LOCATION_TABLE',conn,if_exists='replace',index=False)
conn.commit()

# %%
# read excel file to insert into table column
dataframe_TARGET_GROUP_TABLE = pd.read_excel('/content/Target Group.xlsx')
dataframe_TARGET_GROUP_TABLE.to_sql('TARGET_GROUP_TABLE',conn,if_exists='replace',index=False)
conn.commit()

# %%
# read excel file to insert into table column
dataframe_VACCINE_TABLE = pd.read_excel('/content/Vaccine Table.xlsx')
dataframe_VACCINE_TABLE.to_sql('VACCINE_TABLE',conn,if_exists='replace',index=False)
conn.commit()

# %%
# read excel file to insert into table column
dataframe_COVID_FACT_TABLE = pd.read_excel('/content/Covid-19 FactTable.xlsx')
dataframe_COVID_FACT_TABLE.to_sql('COVID19_FACT_TABLE',conn,if_exists='replace',index=False)
conn.commit()

# %%
#CHECK IF DATA INSERTED INTO TABLE TIME_TABLE
TIME_TABLE = pd.read_sql('SELECT * FROM TIME_TABLE', conn)
TIME_TABLE
# Out:
#       T_ID  Year      Month                 Date
# 0   202101  2021    January  2021-01-01 00:00:00
# 1   202102  2021   February  2021-02-01 00:00:00
# 2   202103  2021      March  2021-03-01 00:00:00
# 3   202104  2021      April  2021-04-01 00:00:00
# 4   202105  2021        May  2021-05-01 00:00:00
# 5   202106  2021       June  2021-06-01 00:00:00
# 6   202107  2021       July  2021-07-01 00:00:00
# 7   202108  2021     August  2021-08-01 00:00:00
# 8   202109  2021  September  2021-09-01 00:00:00
# 9   202110  2021    October  2021-10-01 00:00:00
# 10  202111  2021   November  2021-11-01 00:00:00
# 11  202112  2021   December  2021-12-01 00:00:00

# %%
#CHECK IF DATA INSERTED INTO TABLE VIRUS_TABLE
VIRUS_TABLE = pd.read_sql('SELECT * FROM VIRUS_TABLE', conn)
VIRUS_TABLE
# Out:
#    V_ID      Name        Type
# 0     1  SARS-CoV  SARS-CoV-2

# %%
#CHECK IF DATA INSERTED INTO TABLE VACCINE_TABLE
VACCINE_TABLE = pd.read_sql('SELECT * FROM VACCINE_TABLE', conn)
VACCINE_TABLE
# Out:
#    Vac_ID   Name
# 0     111    COM
# 1     222    UNK
# 2     333  JANSS
# 3     444   NVXD

# %%
#CHECK IF DATA INSERTED INTO TABLE LOCATION_TABLE
LOCATION_TABLE = pd.read_sql('SELECT * FROM LOCATION_TABLE', conn)
LOCATION_TABLE
# Out:
#   L_ID   Country          Region  Population
# 0   GE   Germany          Europe     1500000
# 1   PE     Paris          Europe     1600000
# 2  SUK  Scotland  United Kingdom     1700000
# 3  EUK   England  United Kingdom     1800000

# %%
#CHECK IF DATA INSERTED INTO TABLE TARGET_GROUP_TABLE
TARGET_GROUP_TABLE = pd.read_sql('SELECT * FROM TARGET_GROUP_TABLE', conn)
TARGET_GROUP_TABLE
# Out:
#    Trg_ID Age-Range
# 0       1       ALL

# %%
#CHECK IF DATA INSERTED INTO TABLE COVID19_FACT_TABLE
COVID19_FACT_TABLE= pd.read_sql('SELECT * FROM COVID19_FACT_TABLE', conn)
COVID19_FACT_TABLE
# Out:
#       T_ID L_ID  V_ID  Vac_ID  Trg_ID  Current_Cases  New_Cases  \
# 0   202101   GE     1     111       1        1000000     200000
# 1   202102   GE     1     111       1         800000      55450
# 2   202103   GE     1     111       1         799930      60700
# 3   202104   GE     1     111       1         757847      14670
# 4   202105   GE     1     111       1         695367      18870
# 5   202106   GE     1     111       1         645617      23050
# 6   202107   GE     1     111       1         647577      33760
# 7   202108   GE     1     111       1         596657      75800
# 8   202109   GE     1     111       1         591877      94000
# 9   202110   GE     1     111       1         638547      23320
# 10  202111   GE     1     111       1         573205      42600
# 11  202112   GE     1     111       1         550325      14680
# 12  202101   PE     1     222       1        1000000     200000
# 13  202102   PE     1     222       1         800000      15450
# 14  202103   PE     1     222       1         767930      80703
# 15  202104   PE     1     222       1         779830      14650
# 16  202105   PE     1     222       1         767330      12880
# 17  202106   PE     1     222       1         681510      22050
# 18  202107   PE     1     222       1         653460      34780
# 19  202108   PE     1     222       1         598000      45850
# 20  202109   PE     1     222       1         587030      73507
# 21  202110   PE     1     222       1         620207      23320
# 22  202111   PE     1     222       1         527317      32420
# 23  202112   PE     1     222       1         465397      54680
# 24  202101  SUK     1     333       1        1000000     200000
# 25  202102  SUK     1     333       1         867345      17550
# 26  202103  SUK     1     333       1         824380      80703
# 27  202104  SUK     1     333       1         860816      32550
# 28  202105  SUK     1     333       1         849045      12880
# 29  202106  SUK     1     333       1         815143      54330
# 30  202107  SUK     1     333       1         818370      34780
# 31  202108  SUK     1     333       1         792706      32550
# 32  202109  SUK     1     333       1         746841      73407
# 33  202110  SUK     1     333       1         747912      23476
# 34  202111  SUK     1     333       1         691971      45620
# 35  202112  SUK     1     333       1         652043      74680
# 36  202101  EUK     1     444       1        1000000     200000
# 37  202102  EUK     1     444       1         824230      54650
# 38  202103  EUK     1     444       1         783039      32603
# 39  202104  EUK     1     444       1         717847      32550
# 40  202105  EUK     1     444       1         646094      93680
# 41  202106  EUK     1     444       1         632980      38230
# 42  202107  EUK     1     444       1         650095      23780
# 43  202108  EUK     1     444       1         643419      84420
# 44  202109  EUK     1     444       1         689112      74507
# 45  202110  EUK     1     444       1         736471      74576
# 46  202111  EUK     1     444       1         780318      78320
# 47  202112  EUK     1     444       1         826328      56380
#
#     Recovered_Cases  Deaths  Doses_received  First_Dose  Second_Dose  \
# 0            300000  100000           79897       55928        15979
# 1             15070   40450           53071       37150        10614
# 2             12023   90760           65580       45906        13116
# 3             13750   63400           71344       49941        14269
# 4             11020   57600           73627       51539        14725
# 5             10340   10750           79386       55570        15877
# 6             14680   70000           70698       49489        14140
# 7             20230   60350           60419       42293        12084
# 8             16570   30760           57855       40499        11571
# 9             18650   70012           65016       45511        13003
# 10            19700   45780           78780       55146        15756
# 11            13040   47667           76574       53602        15315
# 12           300000  100000           68355       47849        13671
# 13            15070   32450           54966       38476        10993
# 14            12023   56780           63477       44434        12695
# 15            13750   13400           66426       46498        13285
# 16            11020   87680           69023       48316        13805
# 17            10340   39760           66889       46822        13378
# 18            14680   75560           67392       47174        13478
# 19            20250   36570           67507       47255        13501
# 20            16570   23760           59064       41345        11813
# 21            18650   97560           73098       51169        14620
# 22            19780   74560           75741       53019        15148
# 23            13040   34550           56608       39626        11322
# 24           300000   32655           53310       37317        10662
# 25            15070   45445           52588       36812        10518
# 26            12023   32244           71826       50278        14365
# 27            13560   30761           54636       38245        10927
# 28            11020   35762           69634       48744        13927
# 29            10340   40763           51272       35890        10254
# 30            14680   45764           64773       45341        12955
# 31            27650   50765           76668       53668        15334
# 32            16570   55766           63099       44169        12620
# 33            18650   60767           79626       55738        15925
# 34            19780   65768           70133       49093        14027
# 35            13040   70769           63024       44117        12605
# 36           300000   75770           76623       53636        15325
# 37            15070   80771           73610       51527        14722
# 38            12023   85772           71327       49929        14265
# 39            13530   90773           73828       51680        14766
# 40            11020   95774           51135       35795        10227
# 41            10340   10775           57664       40365        11533
# 42            14680   15776           77742       54419        15548
# 43            27650   11077           57609       40326        11522
# 44            15570   11578           51710       36197        10342
# 45            18650   12079           63654       44558        12731
# 46            19730   12580           72732       50912        14546
# 47            13040   13081           52969       37078        10594
#
#     Third_Dose  ICU_Cases             Source
# 0         7990     285605    Country website
# 1         5307     233101    Country website
# 2         6558     189194    Country website
# 3         7134     202314    Country website
# 4         7363     228141    Country website
# 5         7939     245674    Country website
# 6         7070     184550    Country website
# 7         6042     291130    Country website
# 8         5786     180895    Country website
# 9         6502     236466    Country website
# 10        7878     222378    Country website
# 11        7657     165530    Country website
# 12        6836     108427  Healthcare Survey
# 13        5497     176604  Healthcare Survey
# 14        6348     268494  Healthcare Survey
# 15        6643     234051  Healthcare Survey
# 16        6902     236170  Healthcare Survey
# 17        6689     117572  Healthcare Survey
# 18        6739     138488  Healthcare Survey
# 19        6751     279394  Healthcare Survey
# 20        5906     125244  Healthcare Survey
# 21        7310     162178  Healthcare Survey
# 22        7574     110648  Healthcare Survey
# 23        5661     167798  Healthcare Survey
# 24        5331     117681   Hospital Records
# 25        5259     238403   Hospital Records
# 26        7183     150129   Hospital Records
# 27        5464     158152   Hospital Records
# 28        6963     217498   Hospital Records
# 29        5127     208239   Hospital Records
# 30        6477     124416   Hospital Records
# 31        7667     139416   Hospital Records
# 32        6310     251702   Hospital Records
# 33        7963     278883   Hospital Records
# 34        7013     159694   Hospital Records
# 35        6302     160449   Hospital Records
# 36        7662     237073    NHS Application
# 37        7361     121113    NHS Application
# 38        7133     176939    NHS Application
# 39        7383     261285    NHS Application
# 40        5114     289490    NHS Application
# 41        5766     250351    NHS Application
# 42        7774     112153    NHS Application
# 43        5761     127289    NHS Application
# 44        5171     281449    NHS Application
# 45        6365     184540    NHS Application
# 46        7273     131249    NHS Application
# 47        5297     133787    NHS Application

# %%
# Create Materialized view
cur.execute('''CREATE VIEW matz_view AS
                          Select
                          lt.Region as Region,
                          lt.Country as Country,
                          lt.Population as Population,
                          tt.Year as Year,
                          tt.Month as Month,
                          case when tt.Month in ('January') then 1
                          when tt.Month in ('February') then 1
                          when tt.Month in ('March') then 1
                          when tt.Month in ('April') then 2
                          when tt.Month in ('May') then 2
                          when tt.Month in ('June') then 2
                          when tt.Month in ('July') then 3
                          when tt.Month in ('August') then 3
                          when tt.Month in ('September') then 3
                          when tt.Month in ('October') then 4
                          when tt.Month in ('November') then 4
                          when tt.Month in ('December')then 4 end as Quarter,
                          covid.Current_Cases,
                          covid.New_Cases,
                          (covid.Current_cases+covid.New_cases) as Covid_Cases,
                          covid.Deaths as Deaths,
                          covid.ICU_cases as ICU_Cases,
                          covid.Source as Source,
                          vt.Name as Vaccine_Name,
                          ROUND((covid.Doses_received*100.00/lt.Population),2) as Vacc_Rate_Percentage ,
                          vit.Name as Virus_name,
                          ROUND(((covid.Current_cases+covid.New_cases)*100.00/lt.Population),2) as Infection_Rate_Percentage,
                          covid.Doses_received as Doses_Received,
                          covid.First_Dose as First_Dose,
                          covid.Second_Dose as Second_Dose,
                          covid.Third_Dose as Third_Dose,
                          covid.L_ID as L_ID,
                          covid.T_ID as T_ID,
                          covid.V_ID as V_ID,
                          covid.VAC_ID as VAC_ID,
                          covid.Trg_ID as Trg_ID,
                          tt.T_ID as Month_ID

 from COVID19_FACT_TABLE covid
 left join LOCATION_TABLE lt on covid.L_ID=lt.L_ID
 left join TIME_TABLE tt on covid.T_ID=tt.T_ID
 left join VACCINE_TABLE vt on covid.VAC_ID=vt.VAC_ID
 left join VIRUS_TABLE vit on covid.V_ID=vit.V_ID
 left join TARGET_GROUP_TABLE tgt on covid.TRG_ID=tgt.Trg_ID
 group by lt.Region,lt.Country,tt.Month,vt.Name,Source
 order by lt.Region,lt.Country,covid.T_ID,Source;''')
# commit and save changes to database
#conn.commit()
#print(dataframe_query_one.to_string())

# %%
matz_view= pd.read_sql('SELECT * FROM matz_view', conn)
matz_view
# Out:
#             Region   Country  Population  Year      Month  Quarter  \
# 0           Europe   Germany     1500000  2021    January        1
# 1           Europe   Germany     1500000  2021   February        1
# 2           Europe   Germany     1500000  2021      March        1
# 3           Europe   Germany     1500000  2021      April        2
# 4           Europe   Germany     1500000  2021        May        2
# 5           Europe   Germany     1500000  2021       June        2
# 6           Europe   Germany     1500000  2021       July        3
# 7           Europe   Germany     1500000  2021     August        3
# 8           Europe   Germany     1500000  2021  September        3
# 9           Europe   Germany     1500000  2021    October        4
# 10          Europe   Germany     1500000  2021   November        4
# 11          Europe   Germany     1500000  2021   December        4
# 12          Europe     Paris     1600000  2021    January        1
# 13          Europe     Paris     1600000  2021   February        1
# 14          Europe     Paris     1600000  2021      March        1
# 15          Europe     Paris     1600000  2021      April        2
# 16          Europe     Paris     1600000  2021        May        2
# 17          Europe     Paris     1600000  2021       June        2
# 18          Europe     Paris     1600000  2021       July        3
# 19          Europe     Paris     1600000  2021     August        3
# 20          Europe     Paris     1600000  2021  September        3
# 21          Europe     Paris     1600000  2021    October        4
# 22          Europe     Paris     1600000  2021   November        4
# 23          Europe     Paris     1600000  2021   December        4
# 24  United Kingdom   England     1800000  2021    January        1
# 25  United Kingdom   England     1800000  2021   February        1
# 26  United Kingdom   England     1800000  2021      March        1
# 27  United Kingdom   England     1800000  2021      April        2
# 28  United Kingdom   England     1800000  2021        May        2
# 29  United Kingdom   England     1800000  2021       June        2
# 30  United Kingdom   England     1800000  2021       July        3
# 31  United Kingdom   England     1800000  2021     August        3
# 32  United Kingdom   England     1800000  2021  September        3
# 33  United Kingdom   England     1800000  2021    October        4
# 34  United Kingdom   England     1800000  2021   November        4
# 35  United Kingdom   England     1800000  2021   December        4
# 36  United Kingdom  Scotland     1700000  2021    January        1
# 37  United Kingdom  Scotland     1700000  2021   February        1
# 38  United Kingdom  Scotland     1700000  2021      March        1
# 39  United Kingdom  Scotland     1700000  2021      April        2
# 40  United Kingdom  Scotland     1700000  2021        May        2
# 41  United Kingdom  Scotland     1700000  2021       June        2
# 42  United Kingdom  Scotland     1700000  2021       July        3
# 43  United Kingdom  Scotland     1700000  2021     August        3
# 44  United Kingdom  Scotland     1700000  2021  September        3
# 45  United Kingdom  Scotland     1700000  2021    October        4
# 46  United Kingdom  Scotland     1700000  2021   November        4
# 47  United Kingdom  Scotland     1700000  2021   December        4
#
#     Current_Cases  New_Cases  Covid_Cases  Deaths  ...  Doses_Received  \
# 0         1000000     200000      1200000  100000  ...           79897
# 1          800000      55450       855450   40450  ...           53071
# 2          799930      60700       860630   90760  ...           65580
# 3          757847      14670       772517   63400  ...           71344
# 4          695367      18870       714237   57600  ...           73627
# 5          645617      23050       668667   10750  ...           79386
# 6          647577      33760       681337   70000  ...           70698
# 7          596657      75800       672457   60350  ...           60419
# 8          591877      94000       685877   30760  ...           57855
# 9          638547      23320       661867   70012  ...           65016
# 10         573205      42600       615805   45780  ...           78780
# 11         550325      14680       565005   47667  ...           76574
# 12        1000000     200000      1200000  100000  ...           68355
# 13         800000      15450       815450   32450  ...           54966
# 14         767930      80703       848633   56780  ...           63477
# 15         779830      14650       794480   13400  ...           66426
# 16         767330      12880       780210   87680  ...           69023
# 17         681510      22050       703560   39760  ...           66889
# 18         653460      34780       688240   75560  ...           67392
# 19         598000      45850       643850   36570  ...           67507
# 20         587030      73507       660537   23760  ...           59064
# 21         620207      23320       643527   97560  ...           73098
# 22         527317      32420       559737   74560  ...           75741
# 23         465397      54680       520077   34550  ...           56608
# 24        1000000     200000      1200000   75770  ...           76623
# 25         824230      54650       878880   80771  ...           73610
# 26         783039      32603       815642   85772  ...           71327
# 27         717847      32550       750397   90773  ...           73828
# 28         646094      93680       739774   95774  ...           51135
# 29         632980      38230       671210   10775  ...           57664
# 30         650095      23780       673875   15776  ...           77742
# 31         643419      84420       727839   11077  ...           57609
# 32         689112      74507       763619   11578  ...           51710
# 33         736471      74576       811047   12079  ...           63654
# 34         780318      78320       858638   12580  ...           72732
# 35         826328      56380       882708   13081  ...           52969
# 36        1000000     200000      1200000   32655  ...           53310
# 37         867345      17550       884895   45445  ...           52588
# 38         824380      80703       905083   32244  ...           71826
# 39         860816      32550       893366   30761  ...           54636
# 40         849045      12880       861925   35762  ...           69634
# 41         815143      54330       869473   40763  ...           51272
# 42         818370      34780       853150   45764  ...           64773
# 43         792706      32550       825256   50765  ...           76668
# 44         746841      73407       820248   55766  ...           63099
# 45         747912      23476       771388   60767  ...           79626
# 46         691971      45620       737591   65768  ...           70133
# 47         652043      74680       726723   70769  ...           63024
#
#    First_Dose Second_Dose  Third_Dose L_ID    T_ID  V_ID  VAC_ID  Trg_ID  \
# 0       55928       15979        7990   GE  202101     1     111       1
# 1       37150       10614        5307   GE  202102     1     111       1
# 2       45906       13116        6558   GE  202103     1     111       1
# 3       49941       14269        7134   GE  202104     1     111       1
# 4       51539       14725        7363   GE  202105     1     111       1
# 5       55570       15877        7939   GE  202106     1     111       1
# 6       49489       14140        7070   GE  202107     1     111       1
# 7       42293       12084        6042   GE  202108     1     111       1
# 8       40499       11571        5786   GE  202109     1     111       1
# 9       45511       13003        6502   GE  202110     1     111       1
# 10      55146       15756        7878   GE  202111     1     111       1
# 11      53602       15315        7657   GE  202112     1     111       1
# 12      47849       13671        6836   PE  202101     1     222       1
# 13      38476       10993        5497   PE  202102     1     222       1
# 14      44434       12695        6348   PE  202103     1     222       1
# 15      46498       13285        6643   PE  202104     1     222       1
# 16      48316       13805        6902   PE  202105     1     222       1
# 17      46822       13378        6689   PE  202106     1     222       1
# 18      47174       13478        6739   PE  202107     1     222       1
# 19      47255       13501        6751   PE  202108     1     222       1
# 20      41345       11813        5906   PE  202109     1     222       1
# 21      51169       14620        7310   PE  202110     1     222       1
# 22      53019       15148        7574   PE  202111     1     222       1
# 23      39626       11322        5661   PE  202112     1     222       1
# 24      53636       15325        7662  EUK  202101     1     444       1
# 25      51527       14722        7361  EUK  202102     1     444       1
# 26      49929       14265        7133  EUK  202103     1     444       1
# 27      51680       14766        7383  EUK  202104     1     444       1
# 28      35795       10227        5114  EUK  202105     1     444       1
# 29      40365       11533        5766  EUK  202106     1     444       1
# 30      54419       15548        7774  EUK  202107     1     444       1
# 31      40326       11522        5761  EUK  202108     1     444       1
# 32      36197       10342        5171  EUK  202109     1     444       1
# 33      44558       12731        6365  EUK  202110     1     444       1
# 34      50912       14546        7273  EUK  202111     1     444       1
# 35      37078       10594        5297  EUK  202112     1     444       1
# 36      37317       10662        5331  SUK  202101     1     333       1
# 37      36812       10518        5259  SUK  202102     1     333       1
# 38      50278       14365        7183  SUK  202103     1     333       1
# 39      38245       10927        5464  SUK  202104     1     333       1
# 40      48744       13927        6963  SUK  202105     1     333       1
# 41      35890       10254        5127  SUK  202106     1     333       1
# 42      45341       12955        6477  SUK  202107     1     333       1
# 43      53668       15334        7667  SUK  202108     1     333       1
# 44      44169       12620        6310  SUK  202109     1     333       1
# 45      55738       15925        7963  SUK  202110     1     333       1
# 46      49093       14027        7013  SUK  202111     1     333       1
# 47      44117       12605        6302  SUK  202112     1     333       1
#
#     Month_ID
# 0     202101
# 1     202102
# 2     202103
# 3     202104
# 4     202105
# 5     202106
# 6     202107
# 7     202108
# 8     202109
# 9     202110
# 10    202111
# 11    202112
# 12    202101
# 13    202102
# 14    202103
# 15    202104
# 16    202105
# 17    202106
# 18    202107
# 19    202108
# 20    202109
# 21    202110
# 22    202111
# 23    202112
# 24    202101
# 25    202102
# 26    202103
# 27    202104
# 28    202105
# 29    202106
# 30    202107
# 31    202108
# 32    202109
# 33    202110
# 34    202111
# 35    202112
# 36    202101
# 37    202102
# 38    202103
# 39    202104
# 40    202105
# 41    202106
# 42    202107
# 43    202108
# 44    202109
# 45    202110
# 46    202111
# 47    202112
#
# [48 rows x 26 columns]

# %%
# Write query1 from matz_view Materialized view
dataframe_query_one=pd.read_sql_query('''
                          Select
                          Region,
                          Month,
                          sum(Covid_Cases) as Covid_Cases,
                          sum(Deaths) as Deaths,
                          sum(ICU_cases) as ICU_Cases,
                          Source,
                          Vaccine_Name,
                          Vacc_Rate_Percentage



 from matz_view
 group by Region,Month,Vaccine_Name
 order by Region,Month_ID;''',conn)
# commit and save changes to database
#where covid.T_ID=tt.T_ID and covid.L_ID=lt.L_ID
conn.commit()
dataframe_query_one
# Out:
#             Region      Month  Covid_Cases  Deaths  ICU_Cases  \
# 0           Europe    January      1200000  100000     285605
# 1           Europe    January      1200000  100000     108427
# 2           Europe   February       855450   40450     233101
# 3           Europe   February       815450   32450     176604
# 4           Europe      March       860630   90760     189194
# 5           Europe      March       848633   56780     268494
# 6           Europe      April       772517   63400     202314
# 7           Europe      April       794480   13400     234051
# 8           Europe        May       714237   57600     228141
# 9           Europe        May       780210   87680     236170
# 10          Europe       June       668667   10750     245674
# 11          Europe       June       703560   39760     117572
# 12          Europe       July       681337   70000     184550
# 13          Europe       July       688240   75560     138488
# 14          Europe     August       672457   60350     291130
# 15          Europe     August       643850   36570     279394
# 16          Europe  September       685877   30760     180895
# 17          Europe  September       660537   23760     125244
# 18          Europe    October       661867   70012     236466
# 19          Europe    October       643527   97560     162178
# 20          Europe   November       615805   45780     222378
# 21          Europe   November       559737   74560     110648
# 22          Europe   December       565005   47667     165530
# 23          Europe   December       520077   34550     167798
# 24  United Kingdom    January      1200000   32655     117681
# 25  United Kingdom    January      1200000   75770     237073
# 26  United Kingdom   February       884895   45445     238403
# 27  United Kingdom   February       878880   80771     121113
# 28  United Kingdom      March       905083   32244     150129
# 29  United Kingdom      March       815642   85772     176939
# 30  United Kingdom      April       893366   30761     158152
# 31  United Kingdom      April       750397   90773     261285
# 32  United Kingdom        May       861925   35762     217498
# 33  United Kingdom        May       739774   95774     289490
# 34  United Kingdom       June       869473   40763     208239
# 35  United Kingdom       June       671210   10775     250351
# 36  United Kingdom       July       853150   45764     124416
# 37  United Kingdom       July       673875   15776     112153
# 38  United Kingdom     August       825256   50765     139416
# 39  United Kingdom     August       727839   11077     127289
# 40  United Kingdom  September       820248   55766     251702
# 41  United Kingdom  September       763619   11578     281449
# 42  United Kingdom    October       771388   60767     278883
# 43  United Kingdom    October       811047   12079     184540
# 44  United Kingdom   November       737591   65768     159694
# 45  United Kingdom   November       858638   12580     131249
# 46  United Kingdom   December       726723   70769     160449
# 47  United Kingdom   December       882708   13081     133787
#
#                Source Vaccine_Name  Vacc_Rate_Percentage
# 0     Country website          COM                  5.33
# 1   Healthcare Survey          UNK                  4.27
# 2     Country website          COM                  3.54
# 3   Healthcare Survey          UNK                  3.44
# 4     Country website          COM                  4.37
# 5   Healthcare Survey          UNK                  3.97
# 6     Country website          COM                  4.76
# 7   Healthcare Survey          UNK                  4.15
# 8     Country website          COM                  4.91
# 9   Healthcare Survey          UNK                  4.31
# 10    Country website          COM                  5.29
# 11  Healthcare Survey          UNK                  4.18
# 12    Country website          COM                  4.71
# 13  Healthcare Survey          UNK                  4.21
# 14    Country website          COM                  4.03
# 15  Healthcare Survey          UNK                  4.22
# 16    Country website          COM                  3.86
# 17  Healthcare Survey          UNK                  3.69
# 18    Country website          COM                  4.33
# 19  Healthcare Survey          UNK                  4.57
# 20    Country website          COM                  5.25
# 21  Healthcare Survey          UNK                  4.73
# 22    Country website          COM                  5.10
# 23  Healthcare Survey          UNK                  3.54
# 24   Hospital Records        JANSS                  3.14
# 25    NHS Application         NVXD                  4.26
# 26   Hospital Records        JANSS                  3.09
# 27    NHS Application         NVXD                  4.09
# 28   Hospital Records        JANSS                  4.23
# 29    NHS Application         NVXD                  3.96
# 30   Hospital Records        JANSS                  3.21
# 31    NHS Application         NVXD                  4.10
# 32   Hospital Records        JANSS                  4.10
# 33    NHS Application         NVXD                  2.84
# 34   Hospital Records        JANSS                  3.02
# 35    NHS Application         NVXD                  3.20
# 36   Hospital Records        JANSS                  3.81
# 37    NHS Application         NVXD                  4.32
# 38   Hospital Records        JANSS                  4.51
# 39    NHS Application         NVXD                  3.20
# 40   Hospital Records        JANSS                  3.71
# 41    NHS Application         NVXD                  2.87
# 42   Hospital Records        JANSS                  4.68
# 43    NHS Application         NVXD                  3.54
# 44   Hospital Records        JANSS                  4.13
# 45    NHS Application         NVXD                  4.04
# 46   Hospital Records        JANSS                  3.71
# 47    NHS Application         NVXD                  2.94

# %%
# Rewrite query2 from matz_view Materialized view
dataframe_query_one=pd.read_sql_query('''
                          Select
                          Country,
                          case when Month in ('January') then 1
                          when Month in ('February') then 1
                          when Month in ('March') then 1
                          when Month in ('April') then 2
                          when Month in ('May') then 2
                          when Month in ('June') then 2
                          when Month in ('July') then 3
                          when Month in ('August') then 3
                          when Month in ('September') then 3
                          when Month in ('October') then 4
                          when Month in ('November') then 4
                          when Month in ('December')then 4 end as Quarter,
                          sum(Covid_Cases) as Covid_Cases,
                          sum(Deaths) as Deaths,
                          sum(ICU_cases) as ICU_Cases,
                          Vaccine_Name,
                          Vacc_Rate_Percentage

 from matz_view
 group by Country,Quarter,Vaccine_Name
 order by Country,Quarter;''',conn)
# commit and save changes to database
#where covid.T_ID=tt.T_ID and covid.L_ID=lt.L_ID
conn.commit()
dataframe_query_one
# Out:
#      Country  Quarter  Covid_Cases  Deaths  ICU_Cases Vaccine_Name  \
# 0    England        1      2894522  242313     535125         NVXD
# 1    England        2      2161381  197322     801126         NVXD
# 2    England        3      2165333   38431     520891         NVXD
# 3    England        4      2552393   37740     449576         NVXD
# 4    Germany        1      2916080  231210     707900          COM
# 5    Germany        2      2155421  131750     676129          COM
# 6    Germany        3      2039671  161110     656575          COM
# 7    Germany        4      1842677  163459     624374          COM
# 8      Paris        1      2864083  189230     553525          UNK
# 9      Paris        2      2278250  140840     587793          UNK
# 10     Paris        3      1992627  135890     543126          UNK
# 11     Paris        4      1723341  206670     440624          UNK
# 12  Scotland        1      2989978  110344     506213        JANSS
# 13  Scotland        2      2624764  107286     583889        JANSS
# 14  Scotland        3      2498654  152295     515534        JANSS
# 15  Scotland        4      2235702  197304     599026        JANSS
#
#     Vacc_Rate_Percentage
# 0                   4.26
# 1                   4.10
# 2                   4.32
# 3                   3.54
# 4                   5.33
# 5                   4.76
# 6                   4.71
# 7                   4.33
# 8                   4.27
# 9                   4.15
# 10                  4.21
# 11                  4.57
# 12                  3.14
# 13                  3.21
# 14                  3.81
# 15                  4.68
